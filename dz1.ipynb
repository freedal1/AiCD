# %%
# 1
def check_brackets(input_string):
    stack = []
    opening_brackets = '({['
    closing_brackets = ')}]'
    matching_brackets = {')': '(', '}': '{', ']': '['}

    for char in input_string:
        if char in opening_brackets:
            stack.append(char)
        elif char in closing_brackets:
            if not stack or stack.pop() != matching_brackets[char]:
                return False

    return not stack

# Примеры строк для проверки
correct_string = '((dsasdas((das(d)das)d)asd)da)'
incorrect_string = '(f(gfhd((hgfdg((fghh)dads)das))ds)adddads())))'

print(check_brackets(correct_string))  # Выведет True
print(check_brackets(incorrect_string))  # Выведет False
# Out:
# True
# False

# %%
# 2
class Stack:
    def __init__(self, max_size):
        self.stack = []
        self.max_size = max_size

    def push(self, e):
        if len(self.stack) < self.max_size:
            self.stack.append(e)
        else:
            raise Exception("Stack is full")

    def pop(self):
        if self.is_empty():
            raise Exception("Stack is empty")
        return self.stack.pop()

    def top(self):
        if self.is_empty():
            raise Exception("Stack is empty")
        return self.stack[-1]

    def is_empty(self):
        return len(self.stack) == 0

    def __len__(self):
        return len(self.stack)


# Пример использования
s = Stack(5)
print(s.is_empty())  # True
s.push(1)
s.push(2)
s.push(3)
print(len(s))  # 3
print(s.top())  # 3
print(s.pop())  # 3
print(len(s))  # 2
print(s.is_empty())  # False
# Out:
# True
# 3
# 3
# 3
# 2
# False

# %%
# 3
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def add_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def print_list(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next
# Создаем экземпляр связанного списка
sll = SinglyLinkedList()

# Добавляем элементы в начало списка
sll.add_at_beginning(3)
sll.add_at_beginning(2)
sll.add_at_beginning(1)

# Выводим список на экран
sll.print_list()
# Out:
# 1
# 2
# 3

# %%
# 4
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None  # указатель на предыдущий узел
        self.next = None  # указатель на следующий узел
class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def add_to_beginning(self, data):
        new_node = Node(data)
        if self.head is None:  # Если список пуст
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node

    def print_list(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next
# Создаем двунаправленный связанный список
dll = DoublyLinkedList()

# Добавляем элементы в начало списка
dll.add_to_beginning(3)
dll.add_to_beginning(2)
dll.add_to_beginning(1)

# Выводим элементы списка
dll.print_list()
# Out:
# 1
# 2
# 3

# %%
# 5
class Node:

    def __init__(self, value=None, next_node=None, previous_node=None):
        self.value = value
        self.next_node = next_node
        self.previous_node = previous_node


class LinkedList:

    def __init__(self, *elems):
        previous = None
        nodes = []
        for elem in elems:
            node = Node(elem)
            if previous is not None:
                previous.next_node = node
                node.previous_node = previous
            previous = node
            nodes.append(node)
        self.head = None if list(nodes) == 0 else nodes[0]
        self.tail = None if list(nodes) == 0 else nodes[-1]

    def add_to_beginning(self, elem):
        if self.head is None and self.tail is None:
            self.head = self.tail = Node(elem)
        else:
            new_node = Node(elem)
            new_node.next_node = self.list[0]
            self.list[0].previous_node = new_node
            self.head = new_node
            self.list = [new_node]+self.list


class Queue(LinkedList):

    def __init__(self, *elems):
        super().__init__(elems)

    def enqueue(self, elem):
        if self.head is None and self.tail is None:
            self.head = self.tail = Node(elem)
        else:
            new_node = Node(elem)
            new_node.previous_node = self.previous_node
            self.previous_node.next_node = new_node
            self.tail = new_node

    def dequeue(self):
        if len(self.list) == 0:
            raise IndexError('Очередь пустая')
        return self.list.pop(0).value
